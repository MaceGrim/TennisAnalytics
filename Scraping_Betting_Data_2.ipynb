# %%
from pyquery import PyQuery as pq
from selenium import webdriver
import pandas as pd

# %%
browser = webdriver.PhantomJS()
url = 'http://www.oddsportal.com/search/results/:AZg49Et9/'
browser.get(url)
html = browser.find_element_by_id('col-content').get_attribute('innerHTML')
browser.quit()
table = pq(html)
cols = [th.text() for th in table('value').items()]
#data = [
#    [td.text() for td in tr('td').items()]
#    for tr in table('tbody tr').items()]
#df = pd.DataFrame(data, columns=cols)
cols
# Out:
# []

# %%
html
# Out:
# u'\n\t\t\t\t\t<h1>Archive Odds Search: Djokovic Novak</h1>                    <!-- PAGE BODY -->\n\t\t\t\t\t\n\t\t<form action="/search/" method="post">\n\t\t\t<div class="box">\n\t\t\t\t<div class="corner-form-box">\n\t\t\t\t\t<div class="spc filterOpts">\n\t\t\t\t\t\t<h2>Match Search</h2>\n\t\t\t\t\t\t<input type="text" id="search-match" name="search-event" class="int-text" value="Djokovic Novak">\n\t\t\t\t\t\t<input type="hidden" name="archive" value="1">\n\t\t\t\t\t\t<select id="search-sport" name="search-sport" class="int-select">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="" selected="">All sports</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="soccer">Soccer</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="tennis">Tennis</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="basketball">Basketball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="hockey">Hockey</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="american-football">American Football</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="baseball">Baseball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="handball">Handball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="rugby-union">Rugby Union</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="floorball">Floorball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="bandy">Bandy</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="futsal">Futsal</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="volleyball">Volleyball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="cricket">Cricket</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="darts">Darts</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="snooker">Snooker</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="boxing">Boxing</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="beach-volleyball">Beach Volleyball</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="aussie-rules">Aussie Rules</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="rugby-league">Rugby League</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="badminton">Badminton</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="water-polo">Water polo</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="beach-soccer">Beach Soccer</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="mma">MMA</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="pesapallo">Pes\xe4pallo</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<option value="esports">eSports</option>\n\t\t\t\t\t\t\t\t\t\t\t\t\t</select>\n\t\t\t\t\t\t<button type="submit" name="" class="inline-btn-2 l" value="Show" id="blocked_submit">\n\t\t\t\t\t\t\t<span><span>Show</span></span>\n\t\t\t\t\t\t</button>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t</form>\n\n\t\t\n\n\t\t<div class="box">\n\t\t\t<div class="tab-nav">\n\t\t\t\t<ul>\n\t\t\t\t\t\t\t\t\t\t\t<li id="menu-next-matches">\n\t\t\t\t\t\t\t<a href="/search/:AZg49Et9/"><span>Next Matches</span></a>\n\t\t\t\t\t\t</li>\n\t\t\t\t\t\t<li id="menu-archive-matches" class="last"><strong><span>Results (736)</span></strong></li>\n\t\t\t\t\t\t\t\t\t</ul>\n\t\t\t\t<div class="break"></div>\n\t\t\t</div>\n\t\t\t<table class=" table-main"><colgroup><col width="50"><col width="*"><col width="50"><col width="50"><col width="50"><col width="50"></colgroup><tbody><tr class="dark center" xtid="27768"><th class="first2 tl" colspan="4"><a class="bfl sicona s2" href="/tennis/">Tennis</a><span class="bflp">\xbb</span><a class="bfl" href="/tennis/france/"><span class="ficon f-77">&nbsp;</span>France</a><span class="bflp">\xbb</span><a href="/tennis/france/atp-french-open/">ATP French Open (clay)</a></th><th>1</th><th>2</th><th xparam="Number of available bookmakers odds~2">B\'s</th></tr><tr class="odd deactivate" xeid="jcovr4sM"><td class="table-time datet t1464094500-8-1-0-0 ">Yest., 13:55</td><td class="name table-participant" colspan="2"><a href="/tennis/france/atp-french-open/djokovic-novak-lu-yen-hsun-jcovr4sM/"><span c ...
